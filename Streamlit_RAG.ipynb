# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimi-chuheng/Streamlit_RAG/blob/main/Streamlit_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Streamlit-based RAG with Wikipedia Data

# %%
# !pip install streamlit wikipedia-api sentence-transformers pyngrok
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 40.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 42.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 28.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.6 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import wikipediaapi
from sentence_transformers import SentenceTransformer
from pyngrok import ngrok
import os
import pandas as pd

# Function to fetch Wikipedia summary
def fetch_wikipedia_summary(query):
    wiki = wikipediaapi.Wikipedia(language='en', user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)")
    page = wiki.page(query)
    if page.exists():
        return page.summary
    else:
        return "No Wikipedia page found for the given query."

# %%
print(fetch_wikipedia_summary("Python (programming language)"))
# Out:
# Python is a high-level, general-purpose programming language. Its design philosophy emphasizes code readability with the use of significant indentation.
# Python is dynamically type-checked and garbage-collected. It supports multiple programming paradigms, including structured (particularly procedural), object-oriented and functional programming. It is often described as a "batteries included" language due to its comprehensive standard library.
# Guido van Rossum began working on Python in the late 1980s as a successor to the ABC programming language and first released it in 1991 as Python 0.9.0. Python 2.0 was released in 2000. Python 3.0, released in 2008, was a major revision not completely backward-compatible with earlier versions. Python 2.7.18, released in 2020, was the last release of Python 2.
# Python consistently ranks as one of the most popular programming languages, and has gained widespread use in the machine learning community.

# %%
df = pd.read_csv('GroceryDataset.csv')

all_descriptions = " ".join(df['Product Description'].dropna())

# %%
with open("all_descriptions.txt", "w", encoding="utf-8") as f:
    f.write(all_descriptions)

# %%
import re
def search_product_info(query):
    pattern = re.compile(rf'\b{re.escape(query)}\b', re.IGNORECASE)
    matches = pattern.findall(all_descriptions)

    if matches:
        return f"Found {len(matches)} mentions of '{query}' in descriptions.\n\n{all_descriptions[:500]}"
    else:
        return "No relevant product found."

print(search_product_info("Milk"))
print(search_product_info("Chocolate"))
print(search_product_info("Apple"))
# Out:
# Found 264 mentions of 'Milk' in descriptions.
#
# A cake the dessert epicure will die for!Our Top Selling Cake! Fudge brownie base, layered in velvety smooth peanut butter mousse, rich chocolate cake, topped with brownie chunks, handful of peanut butter chips, drizzled in fudge. This cake is the thoughtful gift idea that’s perfect for family, friends, coworkers, or to anyone you care about in your life. -	Generously sized precut slices, a cake lover’s dreams come true! Includes:Measures 10” diameterWeighs in at 6.8 lbs.14 servings OU-D certifie
# Found 754 mentions of 'Chocolate' in descriptions.
#
# ...

# %%
# Load the sentence transformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# %%writefile app.py

# import streamlit as st
# from sentence_transformers import SentenceTransformer
# import wikipediaapi

# # Load the model
# model = SentenceTransformer('all-MiniLM-L6-v2')

# def fetch_wikipedia_summary(query):
#     wiki = wikipediaapi.Wikipedia(language='en', user_agent="Mozilla/5.0 (compatible; MyBot/0.1; +http://mybot.com/info)")
#     page = wiki.page(query)
#     if page.exists():
#         return page.summary
#     else:
#         return "No Wikipedia page found for the given query."

# st.title("Wikipedia RAG with Streamlit")

# query = st.text_input("Enter a Wikipedia search query:")
# if query:
#     summary = fetch_wikipedia_summary(query)
#     st.write(summary)

# %%
# %%writefile app.py

import streamlit as st
from sentence_transformers import SentenceTransformer

def search_product_info_semantic(query):
    query_embedding = model.encode(query, convert_to_tensor=True)
    description_embedding = model.encode(all_descriptions, convert_to_tensor=True)
    similarity = util.pytorch_cos_sim(query_embedding, description_embedding)

    if similarity.item() > 0.5:
        return f"Relevant information found for '{query}':\n\n{all_descriptions[:500]}"
    else:
        return "No relevant product found."


st.title("Grocery Item Description Search with Streamlit")

query = st.text_input("Enter a grocery item name (e.g., Milk, Apple, Chocolate):")
if query:
    search_method = st.radio("Choose search method:", ("Keyword Search", "Semantic Search"))

    if search_method == "Keyword Search":
        result = search_product_info(query)
    else:
        result = search_product_info_semantic(query)

    st.write(result)
# Out:
# Writing app.py

# %%
os.environ['GOOGLE_API_KEY'] = "AIzaSyCsKnduOw12wY1asUh8rSqQTZGuCYbdPaw"

# %%
# Run the Streamlit app
# !streamlit run app.py &
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.203.188.18:8501
#
#   Stopping...

# %%
# Set up ngrok
# !ngrok authtoken 2or3dnFhxa92dD4YRnYeXYNpknB_7yi2wzs2P7gRwruKL8un4  # Replace with your actual ngrok token

public_url = ngrok.connect(8501)
print(f"Public URL: {public_url}")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public URL: NgrokTunnel: "https://4008-35-203-188-18.ngrok-free.app" -> "http://localhost:8501"
